# %% [markdown]
# ## Public Health Informatics Excercises
#
# We have covered a number of topics about working with data in Python, such as:
# * Importing libraries
# * Loading data
# * Pandas dataframes
# * Cleaning data
# * Visualizing data
# * Returning multiple variables/values from your functions
# * Writing docstrings
# * Defining inner functions
# * Defining default values for function parameters
#
# Now it is time to put these skills to use :)
#
# For this excercise you will use the data from the **BMI** sheet in the **quality_measures_data.xlsx** Excel file.
#
# The data columns you will be working with are defined as follows:
#
# * `TotalPatients`: number of patients seen by provider
# * `BMIOneYear`: number of patients whose BMI has been measured within past year
# * `BMICY`: number of patients whose BMI has been measured within the current year

# %% [markdown]
# ## Task 1: read and clean the data
# Create a Pandas dataframe to read the data rom the **BMI** sheet in the **quality_measures_data.xlsx** Excel file. Once the data has been read, replace `NaN` values in the columns containing counts with `0`. Replace any missing provider ids with `No ID`.
#
# Remember to make efficient use of lambda functions.

# %% [markdown]
# ## Task 2: visualize the data as bar chart
# Make a bar chart of the data that shows how many patients received a BMI measurement with the past year. The chart should look something like this:
#
# <img src="images/number_bmi_tests_bar.png" width="300px"/>
#
# In order to get the bars to sort correctly, you will need to change the values for the quarter. So, write a function that will flip the quarter and year values in the `Quarter` column. For example, value `Q1 2018` is changed to `2018 Q1`.
#
# **Hint:** In order for the y-axis values to have commas, you will need to specify the format for the axis like this:
# ```python
# alt.Y('BMIOneYear',
#        sort="ascending",
#        title="Number of Patients",
#        axis=alt.Axis(format=",.2r")) # this puts commas in the numbers
# ```
#
# If Altair complains about not being about to infer the datatype, you make have to append a datatype designator to the name of the column using a `:` (e.g. `BMIOneYear:Q`). There are three such designators:
# * `O`: for ordinal data
# * `Q`: for quantity data
# * `N`: for nominal

# %% [markdown]
# ## Task 3: visualze data as line chart
# Make a line chart that shows the **percent** of patients that received a BMI measurement within the past year. The chart should look something like this:
#
# <img src="images/percent_bmi_tests_line.png" width="300px"/>
#
# Documentation about Altair's line chart is found here:
# * https://altair-viz.github.io/gallery/line_chart_with_points.html
# * https://altair-viz.github.io/gallery/line_percent.html
#
# **Hint:** In order for the y-axis to use the `%` sign, you will need to specify the format for the axis like this:
# ```python
# alt.Y('BMIOneYear_ratio:Q',
#        sort="ascending",
#        title="Percent of Patients",
#        axis=alt.Axis(format="%")) # this formats y-axis as percents
# ```

# %% [markdown]
# ## Task 3: visualze data as line chart for each group
# Make a line chart that shows the **percent** of patients that received a BMI measurement within the past year for each **group**. The chart should look something like this:
#
# <img src="images/percent_bmi_tests_group_line.png" width="300px"/>
#
# Documentation about Altair's line chart is found here:
# * https://altair-viz.github.io/gallery/multi_series_line.html
