# %% [markdown]
# # SPARQL excercise
# In the SPARQL notebook, you learned the basics querying an ontology. Now we will apply these skills to the `circulatory_organ.owl` ontology located in the ontology folder.
#
# The ontology is loaded using the `rdflib library` like so:
# ```python
# from rdflib import Graph
# ontology = Graph().parse("ontology/circulatory_organ.owl")
# ```

# %% [markdown]
# ## Task 1: selecting subclasses
# Select the subclasses of `blood vessel` (IRI: `http://purl.obolibrary.org/obo/UBERON_0001981`) and print out:
# * IRI of each class
# * Label of each class
# * Definition of each class
#
# Rember to use proper paths to retrieve all subclasses.

# %% [markdown]
# ## Task 2: optional information
# Some classes in the ontology have a `homology_notes` (IRI: `http://purl.obolibrary.org/obo/UBPROP_0000003`) annotation. Select all subclasses of `blood vessel` that have this annotation and include those subclasses that **do not** have this annotation.

# %% [markdown]
# ## Task 3: aggregate query
# Find the number of sublasses of `circulatory organ` (IRI: `http://purl.obolibrary.org/obo/UBERON_0015228`) using an aggregate query.
#
# Next, modify the aggregate query, to count the number of comments (i.e. `rdf:comment`) annotated for each class and filter the results to include only classes having at least one comment.

# %% [markdown]
# ## Task 4: property restrictions
# Using the relation `part of` (IRI: `http://purl.obolibrary.org/obo/BFO_0000050`), find all classes that have been define as part of the `cardiovascular system` (IRI: `http://purl.obolibrary.org/obo/UBERON_0004535`).
#
# In other words, create a query using the property restriction `'part of' some 'cardiovascular system'`.
